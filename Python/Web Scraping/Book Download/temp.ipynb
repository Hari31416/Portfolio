# %%
from Account import Webpage

# %%
web = Webpage('https://www.amazon.com/')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\harik\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
web.get_page()

# %%
web.current_url()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-2be0841c6312> in <module>
# ----> 1 web.current_url()
#
# AttributeError: 'Webpage' object has no attribute 'current_url'

# %%
def wrapper(hello):
    print('Hello')
    hello()
    print('Bye')

# %%
@wrapper
def hello():
    print('Hello')
# Out:
# Hello
# Hello
# Bye

# %%
def decorate(func):
    def inner():
        print('Hello')
        func()
        print('Bye')
    return inner

# %%
def driver():
    driver = webdriver.Chrome()
    driver.get('https://www.amazon.com/')
