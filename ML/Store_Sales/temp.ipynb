# %%
from life_saving_tools.files.notebook import Notebook

nb = Notebook()

# %%
nb.create_content("EDA_and_Feature_Engineering.ipynb")
# Out:
# Converting the Notebook to HTML.
# Looking for the Headers and their positions.
# Getting correct order of the Headers.
# Creating the Contents.
# Content copied to clipboard.

# %%
nb.export_notebook("EDA_and_Feature_Engineering.ipynb")
# Out:
# 'EDA_and_Feature_Engineering.html'

# %%
import zipfile
import os
from IPython.display import FileLink

def zip_dir(directory = os.curdir, file_name = 'directory.zip'):
    """
    zip all the files in a directory
    
    Parameters
    _____
    directory: str
        directory needs to be zipped, defualt is current working directory
        
    file_name: str
        the name of the zipped file (including .zip), default is 'directory.zip'
        
    Returns
    _____
    Creates a hyperlink, which can be used to download the zip file)
    """
    zip_ref = zipfile.ZipFile(file_name, mode='w')
    for folder, _, files in os.walk(directory):
        for file in files:
            if file_name in file:
                pass
            else:
                zip_ref.write(os.path.join(folder, file))
    zip_ref.close()
    return FileLink(file_name)

# %%
train_dir_small = "data/train"
train_dir_large = "data/train_large"
test_dir_small = "data/test"
test_dir_large = "data/test_large"

# %%
zip_dir("data/small", "store_sales_small.zip")
# Out:
# c:\Users\harik\Desktop\Portfolio\ML\Store_Sales\store_sales_small.zip
