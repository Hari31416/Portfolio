# %%
from life_saving_tools.Files import Notebook

# %%
n = Notebook()

# %%
import os
files = os.listdir()
for file in files:
    if file.endswith("ipynb"):
        n.export_notebook(file)

# %%
from sympy import *

# %%
E = Symbol('E')
lambd = Symbol('lambda')

# %%
mat = Matrix([[-E,0,-lambd, 0],[0,-E,0,0],[-lambd,0,-E,0],[0,0,0,-E]])

# %%
mat
# Out:
# Matrix([
# [     -E,  0, -lambda,  0],
# [      0, -E,       0,  0],
# [-lambda,  0,      -E,  0],
# [      0,  0,       0, -E]])

# %%
eq = mat.det()

# %%
solve(eq, E)
# Out:
# [0, -lambda, lambda]

# %%
number = int(input("Enter a number: "))
number

# %%
number
# Out:
# 1
