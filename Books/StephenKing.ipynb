# %%
import pandas as pd

# %%
df = pd.read_html("https://en.wikipedia.org/wiki/Stephen_King_bibliography")

# %%
df[1].drop(["Note", "Publisher", "ISBN"], axis=1, inplace=True)

# %%
df = df[1].iloc[0:62]

# %%
df.to_csv("StephenKing.csv", index=False)
