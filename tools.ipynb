# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
# <td style="border: none;">
# <a target="blank" href="https://colab.research.google.com/github/Hari31416/Portfolio/blob/main/tools.ipynb?hl=en"><img src="https://colab.research.google.com/img/colab_favicon_256px.png" width="28" height="28"/>Run on Google Colab</a></td>
# <td style="border: none;">
# <a target="blank" href="https://github.com/Hari31416/Portfolio/blob/main/tools.ipynb"><img src="https://cdn.icon-icons.com/icons2/2368/PNG/512/github_logo_icon_143772.png" width="28" height="28"/>View on Github</a></td>
# <td style="border: none;">
# </table>

# %%
import os
import pyperclip
import nbformat
from nbconvert import HTMLExporter
import re

# %%
i=0
for folder, _, files in os.walk('.'):
    for file in files:
        if file.endswith('.ipynb'):
            i+=1

print(i)
# Out:
# 40

# %% [markdown]
# ## Changing All notebooks to HTML

# %% [markdown]
# ### Remove Spaces from Folder Names

# %%
directory = r"DL\DLS"

# %%
def remove_chars_from_folder(directory):
    for folder, _, _ in os.walk(directory):
        print(folder)
        try:
            folder_new = folder.replace(' ', '_').replace(".", "_")
            os.rename(folder, folder_new)
        except:
            print('Something went wrong with folder: ', folder)

# %%
remove_chars_from_folder(directory)
# Out:
# DL\DLS
# DL\DLS\C1
# DL\DLS\C1\Assignments
# DL\DLS\C1\Assignments\Building_your_Deep_Neural_Network_Step_by_Step
# DL\DLS\C1\Assignments\Building_your_Deep_Neural_Network_Step_by_Step\.ipynb_checkpoints
# DL\DLS\C1\Assignments\Building_your_Deep_Neural_Network_Step_by_Step\images
# DL\DLS\C1\Assignments\Building_your_Deep_Neural_Network_Step_by_Step\__pycache__
# DL\DLS\C1\Assignments\Deep_Neural_Network_-_Application
# DL\DLS\C1\Assignments\Deep_Neural_Network_-_Application\.ipynb_checkpoints
# DL\DLS\C1\Assignments\Deep_Neural_Network_-_Application\datasets
# DL\DLS\C1\Assignments\Deep_Neural_Network_-_Application\images
# DL\DLS\C1\Assignments\Deep_Neural_Network_-_Application\__pycache__
# DL\DLS\C1\Assignments\Logistic_Regression_with_a_Neural_Network_mindset
# DL\DLS\C1\Assignments\Logistic_Regression_with_a_Neural_Network_mindset\.ipynb_checkpoints
# DL\DLS\C1\Assignments\Logistic_Regression_with_a_Neural_Network_mindset\datasets
# DL\DLS\C1\Assignments\Logistic_Regression_with_a_Neural_Network_mindset\images
# DL\DLS\C1\Assignments\Logistic_Regression_with_a_Neural_Network_mindset\__pycache__
# DL\DLS\C1\Assignments\Planar_data_classification_with_one_hidden_layer
# DL\DLS\C1\Assignments\Planar_data_classification_with_one_hidden_layer\.ipynb_checkpoints
# DL\DLS\C1\Assignments\Planar_data_classification_with_one_hidden_layer\images
# DL\DLS\C1\Assignments\Planar_data_classification_with_one_hidden_layer\__pycache__
# DL\DLS\C1\Notes
# DL\DLS\C2
# DL\DLS\C2\Assignments
# DL\DLS\C2\Assignments\Gradient_Checking
# DL\DLS\C2\Assignments\Gradient_Checking\.ipynb_checkpoints
# DL\DLS\C2\Assignments\Gradient_Checking\images
# DL\DLS\C2\Assignments\Gradient_Checking\__pycache__
# DL\DLS\C2\Assignments\Initialization
# DL\DLS\C2\Assignments\Initialization\.ipynb_checkpoints
# DL\DLS\C2\Assignments\Initialization\__pycache__
# DL\DLS\C2\Assignments\Optimization_Methods
# DL\DLS\C2\Assignments\Optimization_Methods\.ipynb_checkpoints
# DL\DLS\C2\Assignments\Optimization_Methods\datasets
# DL\DLS\C2\Assignments\Optimization_Methods\images
# DL\DLS\C2\Assignments\Optimization_Methods\__pycache__
# DL\DLS\C2\Assignments\Regularization
# DL\DLS\C2\Assignments\Regularization\.ipynb_checkpoints
# DL\DLS\C2\Assignments\Regularization\datasets
# DL\DLS\C2\Assignments\Regularization\images
# DL\DLS\C2\Assignments\Regularization\__pycache__
# DL\DLS\C2\Assignments\Tensorflow_introduction
# DL\DLS\C2\Assignments\Tensorflow_introduction\.ipynb_checkpoints
# DL\DLS\C2\Assignments\Tensorflow_introduction\datasets
# DL\DLS\C2\Assignments\Tensorflow_introduction\images
# DL\DLS\C2\Assignments\Tensorflow_introduction\logs
# DL\DLS\C2\Assignments\Tensorflow_introduction\logs\fit
# DL\DLS\C2\Assignments\Tensorflow_introduction\logs\fit\20200908-171311
# DL\DLS\C2\Assignments\Tensorflow_introduction\logs\fit\20200908-171311\train
# DL\DLS\C2\Assignments\Tensorflow_introduction\logs\fit\20200908-171311\train\plugins
# DL\DLS\C2\Assignments\Tensorflow_introduction\logs\fit\20200908-171311\train\plugins\profile
# DL\DLS\C2\Assignments\Tensorflow_introduction\logs\fit\20200908-171311\train\plugins\profile\2020_09_08_17_13_12
# DL\DLS\C2\Assignments\Tensorflow_introduction\logs\fit\20200908-171311\validation
# DL\DLS\C2\Notes
# DL\DLS\C3
# DL\DLS\C3\Notes

# %%
def remove_chars_from_file(directory, formats = ['ipynb']):
    for folder, _, files in os.walk(directory):
        for file in files:
            for format in formats:
                if file.endswith(format):
                    try:
                        file_new = file.replace(' ', '_')
                        old_file = os.path.join(folder, file)
                        new_file = os.path.join(folder, file_new)
                        os.rename(old_file, new_file)
                    except:
                        print('Something went wrong with file: ', file)

# %%
remove_chars_from_file("ML\DataCamp")

# %% [markdown]
# ### Converting to HTML

# %% [markdown]
# #### Adding Sharing URL

# %%
def convert_notebook(notebook_path):
    notebook = nbformat.read(notebook_path, as_version=4)
    html_exporter = HTMLExporter(template_name="classic")
    colab_url = f"https://colab.research.google.com/github/Hari31416/Portfolio/blob/main/{notebook_path}?hl=en"
    github_url = f"https://github.com/Hari31416/Portfolio/blob/main/{notebook_path}"
    source = f"""<table class="tfo-notebook-buttons" align="left">
<td style="border: none;">
<a target="blank" href="{colab_url}"><img src="https://colab.research.google.com/img/colab_favicon_256px.png" width="28" height="28"/>Run on Google Colab</a></td>
<td style="border: none;">
<a target="blank" href="{github_url}"><img src="https://cdn.icon-icons.com/icons2/2368/PNG/512/github_logo_icon_143772.png" width="28" height="28"/>View on Github</a></td>
<td style="border: none;">
</table>
"""
    notebook['cells'][0]['source'] = source

    (body, _) = html_exporter.from_notebook_node(notebook)

    with open(notebook_path.replace('.ipynb', '.html'), 'w', encoding="utf-8") as f:
        #The Title
        title = notebook_path.split(os.path.sep)[-1].split(".")[0]
        title = title.replace("_", " ").title()
        body = re.sub("<title>Notebook</title>", f"<title>{title}</title>", body)
        #The Source
        f.write(body)

        return notebook_path.replace('.ipynb', '.html')

# %% [markdown]
# #### Converting

# %%
def convert_to_html(directory):
    outputs = []

    for folder, _, files in os.walk(directory):
        if 'checkpoint' in folder:
            continue
        
        for file in files:
            if file.endswith('.ipynb'):
                notebook_path = os.path.join(folder, file)
                output = convert_notebook(notebook_path)
                outputs.append(output)
                print("Converted: ", file)
    return outputs

# %%
outputs = convert_to_html("DL\DLS\C2")
# Out:
# Converted:  Gradient_Checking.ipynb
# Converted:  Initialization.ipynb
# Converted:  Optimization_methods.ipynb
# Converted:  Regularization.ipynb
# Converted:  Tensorflow_introduction.ipynb

# %% [markdown]
# ### Rename all the files to index.html

# %% [markdown]
# #### Remove Previous index.html files

# %%
for folder, _, files in os.walk(directory):
    for file in files:
        if file == 'index.html':
            print("Removing from: ", folder)
            os.remove(os.path.join(folder, file))
# Out:
# Removing from:  ML\DataCamp\Cryptocurrency
# Removing from:  ML\DataCamp\Netflix_Movies
# Removing from:  ML\DataCamp\Nobel_Prize
# Removing from:  ML\DataCamp\Play_Store
# Removing from:  ML\DataCamp\Scala_Language
# Removing from:  ML\DataCamp\Song_Genre
# Removing from:  ML\DataCamp\The_Hottest_Topics_in_Machine_Learning

# %% [markdown]
# #### Renaming all the files to index.html

# %%
for file in outputs:
    file_name = file.split('\\')[-1]
    os.rename(file, file.replace(file_name, 'index.html'))

# %% [markdown]
# ### Getting the HTML Code

# %%
outputs[0]
# Out:
# 'DL\\DLS\\C2\\Assignments\\Gradient_Checking\\Gradient_Checking.html'

# %%
# projects = os.listdir("ML\DataCamp")
text = ""
for output in outputs:
    title = output.split('\\')[-1].split('.')[0]
    output = output.split('\\')[1:-1]
    output = '\\'.join(output)
    
    text+=f"""<li>
    <a href="{output}\" target='blank'>{title.replace("_", " ")}</a>
</li>"""

# %%
pyperclip.copy(text)

# %%
print(text)
# Out:
# <li>
#     <a href="DLS\C1\Assignments\Building_your_Deep_Neural_Network_Step_by_Step" target='blank'>Building your Deep Neural Network Step by Step</a>
# </li><li>
#     <a href="DLS\C1\Assignments\Deep_Neural_Network_-_Application" target='blank'>Deep Neural Network - Application</a>
# </li><li>
#     <a href="DLS\C1\Assignments\Logistic_Regression_with_a_Neural_Network_mindset" target='blank'>Logistic Regression with a Neural Network mindset</a>
# </li><li>
#     <a href="DLS\C1\Assignments\Planar_data_classification_with_one_hidden_layer" target='blank'>Planar data classification with one hidden layer</a>
# </li>

# %% [markdown]
# ## Adding Sharing Url

# %%
def convert_notebook(notebook_path):
    notebook = nbformat.read(notebook_path, as_version=4)
    html_exporter = HTMLExporter(template_name="classic")
    colab_url = f"https://colab.research.google.com/github/Hari31416/Portfolio/blob/main/{notebook_path}?hl=en"
    github_url = f"https://github.com/Hari31416/Portfolio/blob/main/{notebook_path}"
    source = f"""<table class="tfo-notebook-buttons" align="left">
<td style="border: none;">
<a target="blank" href="{colab_url}"><img src="https://colab.research.google.com/img/colab_favicon_256px.png" width="28" height="28"/>Run on Google Colab</a></td>
<td style="border: none;">
<a target="blank" href="{github_url}"><img src="https://cdn.icon-icons.com/icons2/2368/PNG/512/github_logo_icon_143772.png" width="28" height="28"/>View on Github</a></td>
<td style="border: none;">
</table>
"""
    notebook['cells'].insert(0, nbformat.v4.new_markdown_cell(source))

    (body, _) = html_exporter.from_notebook_node(notebook)

    with open(notebook_path.replace('.ipynb', '.html'), 'w', encoding="utf-8") as f:
        #The Title
        title = notebook_path.split(os.path.sep)[-1].split(".")[0]
        title = title.replace("_", " ").title()
        body = re.sub("<title>Notebook</title>", f"<title>{title}</title>", body)
        #The Source
        f.write(body)

        return notebook_path.replace('.ipynb', '.html')

# %%
convert_notebook(r"ML\DataCamp\Netflix_Movies\Investigating_Netflix_Movies_and_Guest_Stars_in_The_Office.ipynb")
# Out:
# 'ML\\DataCamp\\Netflix_Movies\\Investigating_Netflix_Movies_and_Guest_Stars_in_The_Office.html'

# %%
new_text = f"output dos -20 20 10000 0.0{str(4*2)}"

# %%
new_text
# Out:
# 'output dos -20 20 10000 0.08'
