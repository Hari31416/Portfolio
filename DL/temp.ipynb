# %%
from life_saving_tools.files.notebook import Notebook

# %%
n = Notebook()

# %%
n.create_content(r"TensorFlow_Speech_Recognition\tensorflow_speech_recognition_challenge.ipynb")
# Out:
# Converting the Notebook to HTML.
# Looking for the Headers and their positions.
# Getting correct order of the Headers.
# Creating the Contents.
# Content copied to clipboard.

# %%
n.export_notebook(r"TensorFlow_Speech_Recognition\tensorflow_speech_recognition_challenge.ipynb")
# Out:
# 'TensorFlow_Speech_Recognition\\tensorflow_speech_recognition_challenge.html'
