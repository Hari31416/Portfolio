# %%
import mysql.connector
import pandas as pd

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Hari@MySQL",
  database="movies"
)
print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x7f446a7b2e80>

# %%
cursor = mydb.cursor()

# %%
cursor.execute("SHOW DATABASES")

# %%
for x in cursor:
  print(x)
# Out:
# ('information_schema',)
# ('movies',)
# ('mysql',)
# ('netflix',)
# ('performance_schema',)
# ('sys',)
# ('test',)

# %%
cursor.execute("SHOW TABLES")

# %%
for x in cursor:
  print(x[0])
# Out:
# country
# department
# gender
# genre
# keyword
# language
# language_role
# movie
# movie_cast
# movie_company
# movie_crew
# movie_genres
# movie_keywords
# movie_languages
# person
# production_company
# production_country

# %%
cursor.execute("SELECT * FROM movie")

# %%
res = cursor.fetchmany(5)

# %%
pd.DataFrame(res)
# Out:
#    0                                                  1          2   \
# 0  16                                 Dancer in the Dark   12800000
# 1  18                                  The Fifth Element   90000000
# 2  19                                         Metropolis   92620000
# 3  20                                 My Life Without Me          0
# 4  22  Pirates of the Caribbean: The Curse of the Bla...  140000000
#
#                                                   3   \
# 0
# 1
# 2
# 3  http://www.clubcultura.com/clubcine/clubcineas...
# 4  http://disney.go.com/disneyvideos/liveaction/p...
#
#                                                   4           5           6   \
# 0  Selma, a Czech immigrant on the verge of blind...   22.022228  2000-05-17
# 1  In 2257, a taxi driver is unintentionally give...  109.528572  1997-05-07
# 2  In a futuristic city sharply divided between t...   32.351527  1927-01-10
# 3  A Pedro Almodovar production in which a fatall...    7.958831  2003-03-07
# 4  Jack Sparrow, a freewheeling 17th-century pira...  271.972889  2003-07-09
#
#           7    8         9   \
# 0   40031879  140  Released
# 1  263920180  126  Released
# 2     650422  153  Released
# 3    9726954  106  Released
# 4  655011224  143  Released
#
#                                                   10    11    12
# 0                        You don't need eyes to see.  7.60   377
# 1                     There is no future without it.  7.30  3885
# 2  There can be no understanding between the hand...  8.00   657
# 3                                                     7.20    77
# 4              Prepare to be blown out of the water.  7.50  6985
