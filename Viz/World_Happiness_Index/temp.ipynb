# %%
# !kaggle datasets download -d unsdsn/world-happiness
# Out:
# ...
#   0%|          | 0.00/36.8k [00:00<?, ?B/s]
# 100%|██████████| 36.8k/36.8k [00:00<00:00, 3.77MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('raw.zip', 'r')
zip_ref.extractall()

# %%
zip_ref.close()
