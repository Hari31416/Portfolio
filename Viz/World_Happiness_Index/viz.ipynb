# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifteen = pd.read_csv('2015.csv')

# %%
fifteen.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
fifteen.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
fifteen.describe().T.drop("count", axis=1)
# Out:
#                                     mean        std      min        25%  \
# Happiness Rank                 79.493671  45.754363  1.00000  40.250000
# Happiness Score                 5.375734   1.145010  2.83900   4.526000
# Standard Error                  0.047885   0.017146  0.01848   0.037268
# Economy (GDP per Capita)        0.846137   0.403121  0.00000   0.545808
# Family                          0.991046   0.272369  0.00000   0.856823
# Health (Life Expectancy)        0.630259   0.247078  0.00000   0.439185
# Freedom                         0.428615   0.150693  0.00000   0.328330
# Trust (Government Corruption)   0.143422   0.120034  0.00000   0.061675
# Generosity                      0.237296   0.126685  0.00000   0.150553
# Dystopia Residual               2.098977   0.553550  0.32858   1.759410
#
#                                      50%         75%        max
# Happiness Rank                 79.500000  118.750000  158.00000
# ...

# %%
fifteen.groupby("Region").mean().drop("Happiness Rank", axis=1)
# Out:
#                                  Happiness Score  Standard Error  \
# Region
# Australia and New Zealand               7.285000        0.037270
# Central and Eastern Europe              5.332931        0.045208
# Eastern Asia                            5.626167        0.037225
# Latin America and Caribbean             6.144682        0.061127
# Middle East and Northern Africa         5.406900        0.046337
# North America                           7.273000        0.036960
# Southeastern Asia                       5.317444        0.042691
# Southern Asia                           4.580857        0.032161
# Sub-Saharan Africa                      4.202800        0.055299
# Western Europe                          6.689619        0.037625
#
#                                  Economy (GDP per Capita)    Family  \
# Region
# Australia and New Zealand                        1.291880  1.314450
# Central and Eastern Europe                       0.942438  1.053042
# ...
