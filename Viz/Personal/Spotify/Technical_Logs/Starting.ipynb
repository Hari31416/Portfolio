# %%
import glob, os, json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from style import Style

# %% [markdown]
# - Ap_Share
# - InAppBrowserEvent
# - Ap_EndSong
# - ContinuumSectionResponseV1
# - AuthorizationCodeRequestSuccess
# - OAuthAuthCodeGrant
# - OfflineReport
# - AddedToPlaylist
# - LocalFilesReport
# - DesktopPerformanceIssue
# - StudentVerificationStepClick

# %%
json_files = glob.glob('MyData/*.json')
len(json_files)
# Out:
# 170

# %%
def info_one(file, i):
    df = pd.read_json(file)
    m, n = df.shape
    print(Style.MAGENTA + f"Showing {i} of {len(json_files)}")
    print(Style.HEADER + f"File: {file.split(os.path.sep)[-1]}" + Style.END)
    print(Style.OKBLUE + f"File Size: {os.path.getsize(file)/8/1024:.4f} KB" + Style.END)
    print(Style.BLUE + f"Number of Rows: {m}" + Style.END)
    print(Style.CYAN + f"Number of Columns: {n}" + Style.END)
    print(Style.GREEN + f"Columns: {' || '.join(list(df.columns))}" + Style.END)
    print("\n")

# %%
info_one(json_files[0], 0)
# Out:
# Showing 0 of 170
# File: A11yFeatureUsage.json
# File Size: 0.5033 KB
# Number of Rows: 9
# Number of Columns: 14
# Columns: message_any || message_audio_cues || message_display_modified || message_input_alternatives || message_text_size || timestamp_utc || context_application_version || context_conn_country || context_device_manufacturer || context_device_model || context_os_name || context_os_version || context_receiver_service_timestamp || context_time

# %%
for file in json_files:
    info_one(file)
# Out:
# File: A11yFeatureUsage.json
# File Size: 0.5033 KB
# Number of Rows: 9
# Number of Columns: 14
# Columns: Index(['message_any', 'message_audio_cues', 'message_display_modified',
#        'message_input_alternatives', 'message_text_size', 'timestamp_utc',
#        'context_application_version', 'context_conn_country',
#        'context_device_manufacturer', 'context_device_model',
#        'context_os_name', 'context_os_version',
#        'context_receiver_service_timestamp', 'context_time'],
#       dtype='object')
#
#
# File: AccessoryAutoPull.json
# File Size: 0.1149 KB
# Number of Rows: 2
# Number of Columns: 13
# Columns: Index(['message_previous_connected_device_id', 'timestamp_utc',
#        'context_application_version', 'context_conn_country',
#        'context_device_manufacturer', 'context_device_model',
#        'context_os_name', 'context_os_version',
#        'context_receiver_service_timestamp', 'context_time',
#        'message_accessory_type', 'message_app_state',
# ...

# %%
class Style:
    """
    A class which contains the color codes for printing in color
    """

    BLACK = "\033[30m"
    RED = "\033[31m"
    GREEN = "\033[32m"
    YELLOW = "\033[33m"
    BLUE = "\033[34m"
    MAGENTA = "\033[35m"
    CYAN = "\033[36m"
    WHITE = "\033[37m"
    END = "\033[0m"
    HEADER = "\033[95m"
    OKBLUE = "\033[94m"
    OKGREEN = "\033[92m"
    WARNING = "\033[93m"
    FAIL = "\033[91m"
    BOLD = "\033[1m"
    UNDERLINE = "\033[4m"


def sprint(text, option, *args, **kwargs):
    """
    Prints the text with the option provided.
    """

    option_upper = option.upper()
    if option_upper not in Style.__dict__.keys():
        raise ValueError(f"The option {option} nor found. Available options are: {', '.join(list(Style.__dict__.keys())[2:-2])}")
    print(eval(f"Style.{option_upper}") + str(text) + Style.END, *args, **kwargs)

# %%
import time

for i in range(10):
    sprint(i, "underline", end="\r", sep="\n")
    time.sleep(0.4)
# Out:
# 9
