# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("books_2020.csv")

# %%
len(df)
# Out:
# 111

# %%
df.groupby("Author").count()["Title"].index.__len__()
# Out:
# 18

# %%
df.groupby("Series").count()["Title"].index.__len__()
# Out:
# 34

# %%
df['Number of Pages'].mean()
# Out:
# 479.5855855855856

# %%
df['Number of Pages'].sum()
# Out:
# 53234.0

# %%
df.groupby("Author").count()["Title"].sort_values()[-2:]
# Out:
# Author
# Robert Jordan        15
# Brandon Sanderson    35
# Name: Title, dtype: int64

# %%
df.groupby("Series").count()["Title"].sort_values()
# Out:
# Series
# A Song of Ice and Fire                  1
# The Rithmatist                          1
# Stand Alone                             1
# Elantris                                1
# Warbreaker                              1
# Discworld                               1
# Chronicles of Narnia                    1
# The Dresden Files                       2
# The Mortal Instruments                  2
# The Kingkiller Chronicle                2
# Skyward                                 2
# Red Queen                               2
# Red Rising Saga                         2
# Farseer Trilogy                         2
# Infinity Blade                          2
# Percy Jackson and the Olympians         3
# The Hunger Games                        3
# The Licanius Trilogy                    3
# Magnus Chase and the Gods of Asgard     3
# Legion                                  3
# Cosmere Novella                         3
# Keeper of the Lost Cities               4
# ...

# %%
df[df["Series"]=="Stand Alone"]
# Out:
#     Book Id       Title             Author  ISBN13  My Rating  Average Rating  \
# 63  8868764  White Sand  Brandon Sanderson     NaN          4            4.15
#
#             Publisher  Number of Pages  Year Published  \
# 63  Brandon Sanderson              995             NaN
#
#     Original Publication Year   Date Read  Date Added Bookshelves  Read Count  \
# 63                        NaN  08/20/2020  08/11/2020        read           1
#
#          Series
# 63  Stand Alone

# %%
df[df["Author"] == "Robert Jordan"]
# Out:
#      Book Id                                            Title         Author  \
# 0     228665     The Eye of the World (The Wheel of Time, #1)  Robert Jordan
# 1   16031812           A Memory of Light (Wheel of Time, #14)  Robert Jordan
# 22   1166599     The Gathering Storm (The Wheel of Time, #12)  Robert Jordan
# 55    187065               New Spring (The Wheel of Time, #0)  Robert Jordan
# 64   8253920      Towers of Midnight (The Wheel of Time, #13)  Robert Jordan
# 65     13888         Knife of Dreams (The Wheel of Time, #11)  Robert Jordan
# 66    113435  Crossroads of Twilight (The Wheel of Time, #10)  Robert Jordan
# 67     13891           Winter's Heart (The Wheel of Time, #9)  Robert Jordan
# 68    140974      The Path of Daggers (The Wheel of Time, #8)  Robert Jordan
# 69     13890        A Crown of Swords (The Wheel of Time, #7)  Robert Jordan
# 70     35231            Lord of Chaos (The Wheel of Time, #6)  Robert Jordan
# ...
